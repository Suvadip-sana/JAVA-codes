# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
im=cv2.imread('baboon.tiff',0)
plt.imshow(im,'gray')
plt.title("Baboon")
plt.show()

# %%
im[:10,:10]
# Out:
# array([[145,  56,  49,  89, 137,  90,  62,  33,  71,  77],
#        [116, 101,  40,  67,  90,  54,  65,  46,  92,  60],
#        [ 77, 114,  46,  46,  98,  60,  60,  47, 108, 105],
#        [ 71, 136,  95,  48,  83, 120,  53,  47,  70,  90],
#        [ 87, 122, 132,  50,  76,  87,  74,  50,  56, 118],
#        [ 82,  76, 159,  61,  72,  96,  44,  46,  72,  97],
#        [ 43,  51, 134, 130,  70, 122,  53,  62,  65, 109],
#        [ 33,  51, 111, 153,  87, 119,  48,  59,  99, 163],
#        [ 57,  48,  56, 117, 146, 128,  59,  35,  65, 131],
#        [ 38,  32,  48,  64, 146,  79,  95,  59,  48, 154]], dtype=uint8)

# %%
bit=[]
for i in range(8):
    bitplane=im&(1<<i)
    bit.append(bitplane)
fig=plt.figure(figsize=(8,6))
for i in range(8):
    plt.subplot(2,4,i+1)
    plt.title('Bit plane img '+str(i))
    plt.imshow(bit[i],'gray')
plt.show()
